# %%
import pandas as pd

# %%
data = pd.read_csv('customer_shopping_data.csv')
data
# Out:
#       invoice_no customer_id  gender  age         category  quantity    price  \
# 0        I138884     C241288  Female   28         Clothing         5  1500.40
# 1        I317333     C111565    Male   21            Shoes         3  1800.51
# 2        I127801     C266599    Male   20         Clothing         1   300.08
# 3        I173702     C988172  Female   66            Shoes         5  3000.85
# 4        I337046     C189076  Female   53            Books         4    60.60
# ...          ...         ...     ...  ...              ...       ...      ...
# 99452    I219422     C441542  Female   45         Souvenir         5    58.65
# 99453    I325143     C569580    Male   27  Food & Beverage         2    10.46
# 99454    I824010     C103292    Male   63  Food & Beverage         2    10.46
# 99455    I702964     C800631    Male   56       Technology         4  4200.00
# 99456    I232867     C273973  Female   36         Souvenir         3    35.19
#
# ...

# %% [markdown]
# #### univarient analysis

# %%
data.drop("invoice_no", axis= 1 , inplace= True )

# %%
data
# Out:
#       customer_id  gender  age         category  quantity    price  \
# 0         C241288  Female   28         Clothing         5  1500.40
# 1         C111565    Male   21            Shoes         3  1800.51
# 2         C266599    Male   20         Clothing         1   300.08
# 3         C988172  Female   66            Shoes         5  3000.85
# 4         C189076  Female   53            Books         4    60.60
# ...           ...     ...  ...              ...       ...      ...
# 99452     C441542  Female   45         Souvenir         5    58.65
# 99453     C569580    Male   27  Food & Beverage         2    10.46
# 99454     C103292    Male   63  Food & Beverage         2    10.46
# 99455     C800631    Male   56       Technology         4  4200.00
# 99456     C273973  Female   36         Souvenir         3    35.19
#
#       payment_method invoice_date     shopping_mall
# 0        Credit Card     5/8/2022            Kanyon
# 1         Debit Card   12/12/2021    Forum Istanbul
# ...

# %%
# number of unique elements 
data.customer_id.nunique()
# Out:
# 99457

# %%
data.drop("customer_id", axis= 1 , inplace= True )

# %%
data
# Out:
#        gender  age         category  quantity    price payment_method  \
# 0      Female   28         Clothing         5  1500.40    Credit Card
# 1        Male   21            Shoes         3  1800.51     Debit Card
# 2        Male   20         Clothing         1   300.08           Cash
# 3      Female   66            Shoes         5  3000.85    Credit Card
# 4      Female   53            Books         4    60.60           Cash
# ...       ...  ...              ...       ...      ...            ...
# 99452  Female   45         Souvenir         5    58.65    Credit Card
# 99453    Male   27  Food & Beverage         2    10.46           Cash
# 99454    Male   63  Food & Beverage         2    10.46     Debit Card
# 99455    Male   56       Technology         4  4200.00           Cash
# 99456  Female   36         Souvenir         3    35.19    Credit Card
#
#       invoice_date     shopping_mall
# 0         5/8/2022            Kanyon
# 1       12/12/2021    Forum Istanbul
# ...

# %%
data.gender.value_counts()
# Out:
# gender
# Female    59482
# Male      39975
# Name: count, dtype: int64

# %%
data.gender.value_counts(normalize= True )
# Out:
# gender
# Female    0.598068
# Male      0.401932
# Name: proportion, dtype: float64

# %%
# gender --> categorical

# %%
data.age
# Out:
# 0        28
# 1        21
# 2        20
# 3        66
# 4        53
#          ..
# 99452    45
# 99453    27
# 99454    63
# 99455    56
# 99456    36
# Name: age, Length: 99457, dtype: int64

# %%
data.age.min()
# Out:
# 18

# %%
data.age.max()
# Out:
# 69

# %%
data.age.mean()
# Out:
# 43.42708909377922

# %%
data.age.mode()
# Out:
# 0    37
# Name: age, dtype: int64

# %%
data[ data.age == 37 ]
# Out:
#        gender  age         category  quantity    price payment_method  \
# 163      Male   37         Clothing         5  1500.40           Cash
# 201      Male   37        Cosmetics         3   121.98           Cash
# 208    Female   37         Souvenir         2    23.46    Credit Card
# 450      Male   37  Food & Beverage         5    26.15           Cash
# 485    Female   37             Toys         2    71.68           Cash
# ...       ...  ...              ...       ...      ...            ...
# 99051  Female   37         Clothing         1   300.08    Credit Card
# 99089  Female   37         Souvenir         5    58.65    Credit Card
# 99151    Male   37         Souvenir         4    46.92     Debit Card
# 99333  Female   37  Food & Beverage         3    15.69     Debit Card
# 99447  Female   37             Toys         3   107.52           Cash
#
#       invoice_date      shopping_mall
# 163       9/2/2023  Emaar Square Mall
# 201     23/07/2022       Istinye Park
# ...

# %%
data.age.describe()
# Out:
# count    99457.000000
# mean        43.427089
# std         14.990054
# min         18.000000
# 25%         30.000000
# 50%         43.000000
# 75%         56.000000
# max         69.000000
# Name: age, dtype: float64

# %%
data.age.std()
# Out:
# 14.990053791852299

# %%
data.age.plot(kind = "hist")
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
data
# Out:
#        gender  age         category  quantity    price payment_method  \
# 0      Female   28         Clothing         5  1500.40    Credit Card
# 1        Male   21            Shoes         3  1800.51     Debit Card
# 2        Male   20         Clothing         1   300.08           Cash
# 3      Female   66            Shoes         5  3000.85    Credit Card
# 4      Female   53            Books         4    60.60           Cash
# ...       ...  ...              ...       ...      ...            ...
# 99452  Female   45         Souvenir         5    58.65    Credit Card
# 99453    Male   27  Food & Beverage         2    10.46           Cash
# 99454    Male   63  Food & Beverage         2    10.46     Debit Card
# 99455    Male   56       Technology         4  4200.00           Cash
# 99456  Female   36         Souvenir         3    35.19    Credit Card
#
#       invoice_date     shopping_mall
# 0         5/8/2022            Kanyon
# 1       12/12/2021    Forum Istanbul
# ...

# %%
# category  : categorical

# %%
data.category.value_counts()
# Out:
# category
# Clothing           34487
# Cosmetics          15097
# Food & Beverage    14776
# Toys               10087
# Shoes              10034
# Souvenir            4999
# Technology          4996
# Books               4981
# Name: count, dtype: int64

# %%
data.category.value_counts().plot(kind = "bar")
# Out:
# <AxesSubplot:xlabel='category'>

# %%
data
# Out:
#        gender  age         category  quantity    price payment_method  \
# 0      Female   28         Clothing         5  1500.40    Credit Card
# 1        Male   21            Shoes         3  1800.51     Debit Card
# 2        Male   20         Clothing         1   300.08           Cash
# 3      Female   66            Shoes         5  3000.85    Credit Card
# 4      Female   53            Books         4    60.60           Cash
# ...       ...  ...              ...       ...      ...            ...
# 99452  Female   45         Souvenir         5    58.65    Credit Card
# 99453    Male   27  Food & Beverage         2    10.46           Cash
# 99454    Male   63  Food & Beverage         2    10.46     Debit Card
# 99455    Male   56       Technology         4  4200.00           Cash
# 99456  Female   36         Souvenir         3    35.19    Credit Card
#
#       invoice_date     shopping_mall
# 0         5/8/2022            Kanyon
# 1       12/12/2021    Forum Istanbul
# ...

# %%
data.quantity.value_counts()
# Out:
# quantity
# 3    20149
# 5    19990
# 2    19828
# 1    19767
# 4    19723
# Name: count, dtype: int64

# %%
data.price.min()
# Out:
# 5.23

# %%
data.price.max()
# Out:
# 5250.0

# %%
data.price.mean()
# Out:
# 689.2563209226097

# %%
data.price.std()
# Out:
# 941.1845672157425

# %%
data.price.mean() + data.price.std() * 3
# Out:
# 3512.810022569837

# %%
data.price.mean() - data.price.std() * 3
# Out:
# -2134.297380724618

# %%
pricelimit = data.price.mean() + data.price.std() * 3 
pricelimit
# Out:
# 3512.810022569837

# %%
data [ data.price > pricelimit ]
# Out:
#        gender  age    category  quantity   price payment_method invoice_date  \
# 23       Male   44  Technology         5  5250.0           Cash   26/10/2021
# 53     Female   43  Technology         4  4200.0           Cash   22/02/2022
# 69     Female   44  Technology         5  5250.0    Credit Card   19/11/2021
# 363    Female   67  Technology         5  5250.0           Cash     3/1/2022
# 391      Male   47  Technology         5  5250.0     Debit Card    4/10/2022
# ...       ...  ...         ...       ...     ...            ...          ...
# 99204  Female   21  Technology         4  4200.0    Credit Card    6/12/2021
# 99224  Female   27  Technology         5  5250.0    Credit Card    10/3/2022
# 99234  Female   21  Technology         4  4200.0           Cash   23/06/2021
# 99242  Female   40  Technology         4  4200.0           Cash    10/7/2022
# 99455    Male   56  Technology         4  4200.0           Cash   16/03/2021
#
#           shopping_mall
# ...

# %%
data.price.plot(kind = "hist")
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
data
# Out:
#        gender  age         category  quantity    price payment_method  \
# 0      Female   28         Clothing         5  1500.40    Credit Card
# 1        Male   21            Shoes         3  1800.51     Debit Card
# 2        Male   20         Clothing         1   300.08           Cash
# 3      Female   66            Shoes         5  3000.85    Credit Card
# 4      Female   53            Books         4    60.60           Cash
# ...       ...  ...              ...       ...      ...            ...
# 99452  Female   45         Souvenir         5    58.65    Credit Card
# 99453    Male   27  Food & Beverage         2    10.46           Cash
# 99454    Male   63  Food & Beverage         2    10.46     Debit Card
# 99455    Male   56       Technology         4  4200.00           Cash
# 99456  Female   36         Souvenir         3    35.19    Credit Card
#
#       invoice_date     shopping_mall
# 0         5/8/2022            Kanyon
# 1       12/12/2021    Forum Istanbul
# ...

# %%
data.payment_method.value_counts()
# Out:
# payment_method
# Cash           44447
# Credit Card    34931
# Debit Card     20079
# Name: count, dtype: int64

# %%
rightaway = len(data[ data.payment_method == "Debit Card"] ) + len( data [ data.payment_method == "Cash" ])

# %%
rightaway / data.shape[0] * 100
# Out:
# 64.87828910986657

# %%
data
# Out:
#        gender  age         category  quantity    price payment_method  \
# 0      Female   28         Clothing         5  1500.40    Credit Card
# 1        Male   21            Shoes         3  1800.51     Debit Card
# 2        Male   20         Clothing         1   300.08           Cash
# 3      Female   66            Shoes         5  3000.85    Credit Card
# 4      Female   53            Books         4    60.60           Cash
# ...       ...  ...              ...       ...      ...            ...
# 99452  Female   45         Souvenir         5    58.65    Credit Card
# 99453    Male   27  Food & Beverage         2    10.46           Cash
# 99454    Male   63  Food & Beverage         2    10.46     Debit Card
# 99455    Male   56       Technology         4  4200.00           Cash
# 99456  Female   36         Souvenir         3    35.19    Credit Card
#
#       invoice_date     shopping_mall
# 0         5/8/2022            Kanyon
# 1       12/12/2021    Forum Istanbul
# ...

# %%
data.invoice_date.dtype
# Out:
# dtype('O')

# %%
data["invoice_date"] = pd.to_datetime(data.invoice_date, dayfirst= True )
data
# Out:
#        gender  age         category  quantity    price payment_method  \
# 0      Female   28         Clothing         5  1500.40    Credit Card
# 1        Male   21            Shoes         3  1800.51     Debit Card
# 2        Male   20         Clothing         1   300.08           Cash
# 3      Female   66            Shoes         5  3000.85    Credit Card
# 4      Female   53            Books         4    60.60           Cash
# ...       ...  ...              ...       ...      ...            ...
# 99452  Female   45         Souvenir         5    58.65    Credit Card
# 99453    Male   27  Food & Beverage         2    10.46           Cash
# 99454    Male   63  Food & Beverage         2    10.46     Debit Card
# 99455    Male   56       Technology         4  4200.00           Cash
# 99456  Female   36         Souvenir         3    35.19    Credit Card
#
#       invoice_date     shopping_mall
# 0       2022-08-05            Kanyon
# 1       2021-12-12    Forum Istanbul
# ...

# %%
data.invoice_date.dtype
# Out:
# dtype('<M8[ns]')

# %%
data["day"] = data.invoice_date.dt.day

# %%
data
# Out:
#        gender  age         category  quantity    price payment_method  \
# 0      Female   28         Clothing         5  1500.40    Credit Card
# 1        Male   21            Shoes         3  1800.51     Debit Card
# 2        Male   20         Clothing         1   300.08           Cash
# 3      Female   66            Shoes         5  3000.85    Credit Card
# 4      Female   53            Books         4    60.60           Cash
# ...       ...  ...              ...       ...      ...            ...
# 99452  Female   45         Souvenir         5    58.65    Credit Card
# 99453    Male   27  Food & Beverage         2    10.46           Cash
# 99454    Male   63  Food & Beverage         2    10.46     Debit Card
# 99455    Male   56       Technology         4  4200.00           Cash
# 99456  Female   36         Souvenir         3    35.19    Credit Card
#
#       invoice_date     shopping_mall  day
# 0       2022-08-05            Kanyon    5
# ...

# %%
data["month"] = data.invoice_date.dt.month

# %%
data
# Out:
#        gender  age         category  quantity    price payment_method  \
# 0      Female   28         Clothing         5  1500.40    Credit Card
# 1        Male   21            Shoes         3  1800.51     Debit Card
# 2        Male   20         Clothing         1   300.08           Cash
# 3      Female   66            Shoes         5  3000.85    Credit Card
# 4      Female   53            Books         4    60.60           Cash
# ...       ...  ...              ...       ...      ...            ...
# 99452  Female   45         Souvenir         5    58.65    Credit Card
# 99453    Male   27  Food & Beverage         2    10.46           Cash
# 99454    Male   63  Food & Beverage         2    10.46     Debit Card
# 99455    Male   56       Technology         4  4200.00           Cash
# 99456  Female   36         Souvenir         3    35.19    Credit Card
#
#       invoice_date     shopping_mall  day  month
# 0       2022-08-05            Kanyon    5      8
# ...

# %%
data["year"] = data.invoice_date.dt.year

# %%
data
# Out:
#        gender  age         category  quantity    price payment_method  \
# 0      Female   28         Clothing         5  1500.40    Credit Card
# 1        Male   21            Shoes         3  1800.51     Debit Card
# 2        Male   20         Clothing         1   300.08           Cash
# 3      Female   66            Shoes         5  3000.85    Credit Card
# 4      Female   53            Books         4    60.60           Cash
# ...       ...  ...              ...       ...      ...            ...
# 99452  Female   45         Souvenir         5    58.65    Credit Card
# 99453    Male   27  Food & Beverage         2    10.46           Cash
# 99454    Male   63  Food & Beverage         2    10.46     Debit Card
# 99455    Male   56       Technology         4  4200.00           Cash
# 99456  Female   36         Souvenir         3    35.19    Credit Card
#
#       invoice_date     shopping_mall  day  month  year
# 0       2022-08-05            Kanyon    5      8  2022
# ...

# %%
data["month_year"] = data.invoice_date.dt.to_period("M")

# %%
data
# Out:
#        gender  age         category  quantity    price payment_method  \
# 0      Female   28         Clothing         5  1500.40    Credit Card
# 1        Male   21            Shoes         3  1800.51     Debit Card
# 2        Male   20         Clothing         1   300.08           Cash
# 3      Female   66            Shoes         5  3000.85    Credit Card
# 4      Female   53            Books         4    60.60           Cash
# ...       ...  ...              ...       ...      ...            ...
# 99452  Female   45         Souvenir         5    58.65    Credit Card
# 99453    Male   27  Food & Beverage         2    10.46           Cash
# 99454    Male   63  Food & Beverage         2    10.46     Debit Card
# 99455    Male   56       Technology         4  4200.00           Cash
# 99456  Female   36         Souvenir         3    35.19    Credit Card
#
#       invoice_date     shopping_mall  day  month  year month_year
# ...

# %%
data.shopping_mall.value_counts()
# Out:
# shopping_mall
# Mall of Istanbul     19943
# Kanyon               19823
# Metrocity            15011
# Metropol AVM         10161
# Istinye Park          9781
# Zorlu Center          5075
# Cevahir AVM           4991
# Forum Istanbul        4947
# Viaport Outlet        4914
# Emaar Square Mall     4811
# Name: count, dtype: int64

# %%
data.day
# Out:
# 0         5
# 1        12
# 2         9
# 3        16
# 4        24
#          ..
# 99452    21
# 99453    22
# 99454    28
# 99455    16
# 99456    15
# Name: day, Length: 99457, dtype: int32

# %%
data.day.value_counts()
# Out:
# day
# 3     3426
# 4     3422
# 5     3419
# 7     3401
# 6     3396
# 25    3353
# 21    3344
# 8     3333
# 24    3326
# 19    3318
# 12    3307
# 1     3307
# 14    3299
# 23    3296
# 2     3293
# 10    3281
# 28    3252
# 20    3241
# 22    3238
# 11    3234
# 9     3210
# 15    3204
# 16    3190
# 18    3183
# 26    3179
# 17    3178
# 13    3165
# 27    3137
# 30    2871
# 29    2798
# 31    1856
# Name: count, dtype: int64

# %%
data.month.value_counts()
# Out:
# month
# 1     11608
# 2     10482
# 3      8730
# 7      7877
# 10     7764
# 5      7697
# 12     7680
# 8      7635
# 6      7581
# 11     7563
# 4      7487
# 9      7353
# Name: count, dtype: int64

# %%
data.year.value_counts()
# Out:
# year
# 2022    45551
# 2021    45382
# 2023     8524
# Name: count, dtype: int64

# %%
data[ data.year == 2023].month_year.unique()
# Out:
# <PeriodArray>
# ['2023-03', '2023-02', '2023-01']
# Length: 3, dtype: period[M]

# %%
data[ data.year == 2022].month_year.unique()
# Out:
# <PeriodArray>
# ['2022-08', '2022-05', '2022-03', '2022-12', '2022-10', '2022-07', '2022-11',
#  '2022-06', '2022-01', '2022-04', '2022-02', '2022-09']
# Length: 12, dtype: period[M]

# %%
data[ data.year == 2021].month_year.unique()
# Out:
# <PeriodArray>
# ['2021-12', '2021-11', '2021-05', '2021-10', '2021-01', '2021-08', '2021-07',
#  '2021-04', '2021-09', '2021-06', '2021-03', '2021-02']
# Length: 12, dtype: period[M]

# %%
data.month_year.value_counts()
# Out:
# month_year
# 2021-07    3984
# 2022-03    3947
# 2023-01    3926
# 2021-10    3916
# 2022-08    3912
# 2022-07    3893
# 2021-12    3881
# 2022-05    3849
# 2021-05    3848
# 2022-10    3848
# 2022-01    3847
# 2021-01    3835
# 2021-03    3813
# 2022-12    3799
# 2022-06    3798
# 2021-11    3798
# 2021-06    3783
# 2022-11    3765
# 2022-04    3763
# 2021-04    3724
# 2021-08    3723
# 2022-09    3683
# 2021-09    3670
# 2023-02    3628
# 2022-02    3447
# 2021-02    3407
# 2023-03     970
# Freq: M, Name: count, dtype: int64

# %%
data.month_year.value_counts().plot(kind = "bar")
# Out:
# <AxesSubplot:xlabel='month_year'>

# %%
data
# Out:
#        gender  age         category  quantity    price payment_method  \
# 0      Female   28         Clothing         5  1500.40    Credit Card
# 1        Male   21            Shoes         3  1800.51     Debit Card
# 2        Male   20         Clothing         1   300.08           Cash
# 3      Female   66            Shoes         5  3000.85    Credit Card
# 4      Female   53            Books         4    60.60           Cash
# ...       ...  ...              ...       ...      ...            ...
# 99452  Female   45         Souvenir         5    58.65    Credit Card
# 99453    Male   27  Food & Beverage         2    10.46           Cash
# 99454    Male   63  Food & Beverage         2    10.46     Debit Card
# 99455    Male   56       Technology         4  4200.00           Cash
# 99456  Female   36         Souvenir         3    35.19    Credit Card
#
#       invoice_date     shopping_mall  day  month  year month_year
# ...

# %%
data.groupby("gender").age.mean()
# Out:
# gender
# Female    43.453515
# Male      43.387767
# Name: age, dtype: float64

# %%
data.groupby("gender").age.min()
# Out:
# gender
# Female    18
# Male      18
# Name: age, dtype: int64

# %%
data.groupby("gender").age.max()
# Out:
# gender
# Female    69
# Male      69
# Name: age, dtype: int64

# %%
data.groupby("gender").age.describe()
# Out:
#           count       mean        std   min   25%   50%   75%   max
# gender
# Female  59482.0  43.453515  14.965468  18.0  30.0  43.0  56.0  69.0
# Male    39975.0  43.387767  15.026664  18.0  30.0  43.0  56.0  69.0

# %%
data
# Out:
#        gender  age         category  quantity    price payment_method  \
# 0      Female   28         Clothing         5  1500.40    Credit Card
# 1        Male   21            Shoes         3  1800.51     Debit Card
# 2        Male   20         Clothing         1   300.08           Cash
# 3      Female   66            Shoes         5  3000.85    Credit Card
# 4      Female   53            Books         4    60.60           Cash
# ...       ...  ...              ...       ...      ...            ...
# 99452  Female   45         Souvenir         5    58.65    Credit Card
# 99453    Male   27  Food & Beverage         2    10.46           Cash
# 99454    Male   63  Food & Beverage         2    10.46     Debit Card
# 99455    Male   56       Technology         4  4200.00           Cash
# 99456  Female   36         Souvenir         3    35.19    Credit Card
#
#       invoice_date     shopping_mall  day  month  year month_year
# ...

# %%
pd.crosstab(data.gender , data.category )
# Out:
# category  Books  Clothing  Cosmetics  Food & Beverage  Shoes  Souvenir  \
# gender
# Female     2906     20652       9070             8804   5967      3017
# Male       2075     13835       6027             5972   4067      1982
#
# category  Technology  Toys
# gender
# Female          2981  6085
# Male            2015  4002

# %%
pd.crosstab(data.gender , data.category ).plot(kind = "bar")
# Out:
# <AxesSubplot:xlabel='gender'>

# %%
pd.crosstab(data.category , data.gender ).plot(kind = "bar")
# Out:
# <AxesSubplot:xlabel='category'>

# %%
pd.crosstab(data.gender , data.quantity)
# Out:
# quantity      1      2      3      4      5
# gender
# Female    11824  11812  12046  11927  11873
# Male       7943   8016   8103   7796   8117

# %%
data
# Out:
#        gender  age         category  quantity    price payment_method  \
# 0      Female   28         Clothing         5  1500.40    Credit Card
# 1        Male   21            Shoes         3  1800.51     Debit Card
# 2        Male   20         Clothing         1   300.08           Cash
# 3      Female   66            Shoes         5  3000.85    Credit Card
# 4      Female   53            Books         4    60.60           Cash
# ...       ...  ...              ...       ...      ...            ...
# 99452  Female   45         Souvenir         5    58.65    Credit Card
# 99453    Male   27  Food & Beverage         2    10.46           Cash
# 99454    Male   63  Food & Beverage         2    10.46     Debit Card
# 99455    Male   56       Technology         4  4200.00           Cash
# 99456  Female   36         Souvenir         3    35.19    Credit Card
#
#       invoice_date     shopping_mall  day  month  year month_year
# ...

# %%
data.groupby("gender").price.mean()
# Out:
# gender
# Female    688.137615
# Male      690.920933
# Name: price, dtype: float64

# %%
data.groupby("gender").price.sum()
# Out:
# gender
# Female    40931801.62
# Male      27619564.29
# Name: price, dtype: float64

# %%
pd.crosstab(data.gender , data.payment_method )
# Out:
# payment_method   Cash  Credit Card  Debit Card
# gender
# Female          26509        21011       11962
# Male            17938        13920        8117

# %%
pd.crosstab(data.gender, data.shopping_mall )
# Out:
# shopping_mall  Cevahir AVM  Emaar Square Mall  Forum Istanbul  Istinye Park  \
# gender
# Female                2940               2842            3016          5874
# Male                  2051               1969            1931          3907
#
# shopping_mall  Kanyon  Mall of Istanbul  Metrocity  Metropol AVM  \
# gender
# Female          11906             11902       8941          6144
# Male             7917              8041       6070          4017
#
# shopping_mall  Viaport Outlet  Zorlu Center
# gender
# Female                   2949          2968
# Male                     1965          2107

# %%
pd.crosstab(data.gender, data.shopping_mall ).plot(kind = "bar")
# Out:
# <AxesSubplot:xlabel='gender'>

# %%
pd.crosstab(data.shopping_mall , data.gender ).plot(kind = "bar")
# Out:
# <AxesSubplot:xlabel='shopping_mall'>

# %%
data
# Out:
#        gender  age         category  quantity    price payment_method  \
# 0      Female   28         Clothing         5  1500.40    Credit Card
# 1        Male   21            Shoes         3  1800.51     Debit Card
# 2        Male   20         Clothing         1   300.08           Cash
# 3      Female   66            Shoes         5  3000.85    Credit Card
# 4      Female   53            Books         4    60.60           Cash
# ...       ...  ...              ...       ...      ...            ...
# 99452  Female   45         Souvenir         5    58.65    Credit Card
# 99453    Male   27  Food & Beverage         2    10.46           Cash
# 99454    Male   63  Food & Beverage         2    10.46     Debit Card
# 99455    Male   56       Technology         4  4200.00           Cash
# 99456  Female   36         Souvenir         3    35.19    Credit Card
#
#       invoice_date     shopping_mall  day  month  year month_year
# ...

# %%
pd.crosstab(data.gender , data.category )
# Out:
# category  Books  Clothing  Cosmetics  Food & Beverage  Shoes  Souvenir  \
# gender
# Female     2906     20652       9070             8804   5967      3017
# Male       2075     13835       6027             5972   4067      1982
#
# category  Technology  Toys
# gender
# Female          2981  6085
# Male            2015  4002

# %%
pd.crosstab(data.gender , data.category , values= data.price, aggfunc= "sum")
# Out:
# category     Books     Clothing   Cosmetics  Food & Beverage        Shoes  \
# gender
# Female    132956.4  18616663.12  1108432.26        137873.26  10746644.02
# Male       94020.9  12459021.52   740174.64         93695.45   7388692.87
#
# category   Souvenir  Technology       Toys
# gender
# Female    105288.48   9425850.0  658094.08
# Male       69148.35   6346200.0  428610.56

# %%
pd.crosstab([data.gender, data.category] , data.shopping_mall)
# Out:
# shopping_mall           Cevahir AVM  Emaar Square Mall  Forum Istanbul  \
# gender category
# Female Books                    149                141             152
#        Clothing                1021                951            1065
#        Cosmetics                444                469             465
#        Food & Beverage          446                381             429
#        Shoes                    303                308             261
#        Souvenir                 131                136             152
#        Technology               143                163             139
#        Toys                     303                293             353
# Male   Books                    109                 95             100
#        Clothing                 708                700             664
#        Cosmetics                288                291             305
#        Food & Beverage          326                311             283
# ...

# %%
pd.crosstab(data.gender, [data.category , data.shopping_mall] )
# Out:
# category            Books                                                \
# shopping_mall Cevahir AVM Emaar Square Mall Forum Istanbul Istinye Park
# gender
# Female                149               141            152          263
# Male                  109                95            100          199
#
# category                                                                     \
# shopping_mall Kanyon Mall of Istanbul Metrocity Metropol AVM Viaport Outlet
# gender
# Female           584              607       441          277            141
# Male             429              418       311          199            105
#
# category                    ...        Toys                                   \
# shopping_mall Zorlu Center  ... Cevahir AVM Emaar Square Mall Forum Istanbul
# gender                      ...
# Female                 151  ...         303               293            353
# Male                   110  ...         211               171            178
#
# ...

# %%
pd.crosstab([data.gender, data.category] , data.shopping_mall, values= data.price , aggfunc="sum")
# Out:
# shopping_mall           Cevahir AVM  Emaar Square Mall  Forum Istanbul  \
# gender category
# Female Books                6726.60            6953.85         6999.30
#        Clothing           927547.28          860329.36       961156.24
#        Cosmetics           53630.54           56924.00        58591.06
#        Food & Beverage      6940.21            6045.88         6459.05
#        Shoes              564159.80          526949.26       484337.19
#        Souvenir             4480.86            4797.57         5477.91
#        Technology         452550.00          527100.00       414750.00
#        Toys                33008.64           31431.68        36843.52
# Male   Books                5272.20            4105.65         4454.10
#        Clothing           626867.12          651473.68       610962.88
#        Cosmetics           34764.30           35455.52        36634.66
#        Food & Beverage      5052.18            4984.19         4377.51
# ...

# %%
data
# Out:
#        gender  age         category  quantity    price payment_method  \
# 0      Female   28         Clothing         5  1500.40    Credit Card
# 1        Male   21            Shoes         3  1800.51     Debit Card
# 2        Male   20         Clothing         1   300.08           Cash
# 3      Female   66            Shoes         5  3000.85    Credit Card
# 4      Female   53            Books         4    60.60           Cash
# ...       ...  ...              ...       ...      ...            ...
# 99452  Female   45         Souvenir         5    58.65    Credit Card
# 99453    Male   27  Food & Beverage         2    10.46           Cash
# 99454    Male   63  Food & Beverage         2    10.46     Debit Card
# 99455    Male   56       Technology         4  4200.00           Cash
# 99456  Female   36         Souvenir         3    35.19    Credit Card
#
#       invoice_date     shopping_mall  day  month  year month_year
# ...

# %%
pd.crosstab(data.gender, data.payment_method , values= data.price , aggfunc= "sum")
# Out:
# payment_method         Cash  Credit Card  Debit Card
# gender
# Female          18404851.77  14398910.42  8128039.43
# Male            12300179.21   9652566.51  5666818.57

# %%
pd.crosstab([data.gender, data.payment_method], data.shopping_mall , values= data.price , aggfunc= "sum")
# Out:
# shopping_mall          Cevahir AVM  Emaar Square Mall  Forum Istanbul  \
# gender payment_method
# Female Cash              907889.97          936837.03       806254.17
#        Credit Card       738730.37          684199.57       744036.51
#        Debit Card        402423.59          399495.00       424323.59
# Male   Cash              611433.41          609339.22       623510.11
#        Credit Card       463561.79          482597.83       439577.54
#        Debit Card        309632.71          277939.66       298371.90
#
# shopping_mall          Istinye Park      Kanyon  Mall of Istanbul   Metrocity  \
# gender payment_method
# Female Cash              1781331.81  3820790.61        3689270.66  2684630.26
#        Credit Card       1451800.07  2746639.86        2877221.44  2200256.61
#        Debit Card         809273.11  1678198.99        1615573.43  1220004.15
# Male   Cash              1230677.01  2384431.06        2552508.90  1868152.13
# ...

# %%
data
# Out:
#        gender  age         category  quantity    price payment_method  \
# 0      Female   28         Clothing         5  1500.40    Credit Card
# 1        Male   21            Shoes         3  1800.51     Debit Card
# 2        Male   20         Clothing         1   300.08           Cash
# 3      Female   66            Shoes         5  3000.85    Credit Card
# 4      Female   53            Books         4    60.60           Cash
# ...       ...  ...              ...       ...      ...            ...
# 99452  Female   45         Souvenir         5    58.65    Credit Card
# 99453    Male   27  Food & Beverage         2    10.46           Cash
# 99454    Male   63  Food & Beverage         2    10.46     Debit Card
# 99455    Male   56       Technology         4  4200.00           Cash
# 99456  Female   36         Souvenir         3    35.19    Credit Card
#
#       invoice_date     shopping_mall  day  month  year month_year
# ...

# %%
pd.crosstab(data.year, data.shopping_mall , values= data.price, aggfunc= "sum")
# Out:
# shopping_mall  Cevahir AVM  Emaar Square Mall  Forum Istanbul  Istinye Park  \
# year
# 2021            1576466.41         1627952.65      1517889.61    3054075.88
# 2022            1574997.67         1486693.95      1557865.06    3113886.80
# 2023             282207.76          275761.71       260319.15     549114.86
#
# shopping_mall      Kanyon  Mall of Istanbul   Metrocity  Metropol AVM  \
# year
# 2021           6260081.49        6327493.47  4596979.74    3242670.63
# 2022           6239315.43        6360273.56  4737607.54    3102653.04
# 2023           1211358.32        1163970.59   915392.79     592669.32
#
# shopping_mall  Viaport Outlet  Zorlu Center
# year
# 2021               1558828.64    1553866.11
# 2022               1580092.27    1619440.86
# 2023                275098.55     336342.05

# %%
quarter =  [ ]

for i in data.month: 
    if i <= 3: 
        quarter.append(1)
    elif i <= 6: 
        quarter.append(2)
    elif i <= 9: 
        quarter.append(3)
    else:
        quarter.append(4)

# %%
data["quarter"] = quarter

# %%
data
# Out:
#        gender  age         category  quantity    price payment_method  \
# 0      Female   28         Clothing         5  1500.40    Credit Card
# 1        Male   21            Shoes         3  1800.51     Debit Card
# 2        Male   20         Clothing         1   300.08           Cash
# 3      Female   66            Shoes         5  3000.85    Credit Card
# 4      Female   53            Books         4    60.60           Cash
# ...       ...  ...              ...       ...      ...            ...
# 99452  Female   45         Souvenir         5    58.65    Credit Card
# 99453    Male   27  Food & Beverage         2    10.46           Cash
# 99454    Male   63  Food & Beverage         2    10.46     Debit Card
# 99455    Male   56       Technology         4  4200.00           Cash
# 99456  Female   36         Souvenir         3    35.19    Credit Card
#
#       invoice_date     shopping_mall  day  month  year month_year  quarter
# ...

# %%
pd.crosstab([data.year, data.quarter] , data.shopping_mall , values= data.price , aggfunc= "sum")
# Out:
# shopping_mall  Cevahir AVM  Emaar Square Mall  Forum Istanbul  Istinye Park  \
# year quarter
# 2021 1           369812.45          361920.63       349868.29     723052.70
#      2           366603.50          396455.50       436289.02     724922.57
#      3           400531.52          437561.78       352254.33     797793.56
#      4           439518.94          432014.74       379477.97     808307.05
# 2022 1           382567.62          375017.02       376495.88     821144.68
#      2           411329.67          368393.30       413803.99     751022.20
#      3           425620.55          380139.30       387298.93     751415.68
#      4           355479.83          363144.33       380266.26     790304.24
# 2023 1           282207.76          275761.71       260319.15     549114.86
#
# shopping_mall      Kanyon  Mall of Istanbul   Metrocity  Metropol AVM  \
# year quarter
# 2021 1         1613982.55        1613129.20  1101848.06     802290.52
# ...

# %%
data
# Out:
#        gender  age         category  quantity    price payment_method  \
# 0      Female   28         Clothing         5  1500.40    Credit Card
# 1        Male   21            Shoes         3  1800.51     Debit Card
# 2        Male   20         Clothing         1   300.08           Cash
# 3      Female   66            Shoes         5  3000.85    Credit Card
# 4      Female   53            Books         4    60.60           Cash
# ...       ...  ...              ...       ...      ...            ...
# 99452  Female   45         Souvenir         5    58.65    Credit Card
# 99453    Male   27  Food & Beverage         2    10.46           Cash
# 99454    Male   63  Food & Beverage         2    10.46     Debit Card
# 99455    Male   56       Technology         4  4200.00           Cash
# 99456  Female   36         Souvenir         3    35.19    Credit Card
#
#       invoice_date     shopping_mall  day  month  year month_year  quarter
# ...
